# %%
# Importamos las librerias Panda, Numpy y Matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import os
os.chdir ("C:\Users\Adrian\Downloads\titanic_M1.xlsx")

# %%
# Bajamos archivo titanic
df=pd.read_excel("titanic_M1.xlsx")
df.head(170)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 165     1.0         1                     Hoyt, Mr. Frederick Maxfield
# 166     1.0         0                         Hoyt, Mr. William Fisher
# 167     1.0         1  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# 168     1.0         1                              Icard, Miss. Amelie
# 169     1.0         0                       Isham, Miss. Ann Elizabeth
#
#         sex      age  sibsp  parch    ticket       fare    cabin embarked  \
# ...

# %%
# Veamos de que tamaño es el dataset

# 1219 filas y 14 columnas
df.shape
# Out:
# (1219, 14)

# %%
df.head(170)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 165     1.0         1                     Hoyt, Mr. Frederick Maxfield
# 166     1.0         0                         Hoyt, Mr. William Fisher
# 167     1.0         1  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# 168     1.0         1                              Icard, Miss. Amelie
# 169     1.0         0                       Isham, Miss. Ann Elizabeth
#
#         sex      age  sibsp  parch    ticket       fare    cabin embarked  \
# ...

# %%
# Luego, podemos crear una vista general de los valores con la función “describe()”.
# Lo que nos entregará conteo, media, desviación estándar, min, cuartiles Q1, Q2, Q3 y valor máximo.

df.describe()
# Out:
#             pclass     survived         age        sibsp        parch  \
# count  1143.000000  1219.000000  980.000000  1219.000000  1219.000000
# mean      2.258968     0.394586   30.026276     0.514356     0.400328
# std       0.870486     0.488962   14.465674     1.066930     0.886238
# min       1.000000     0.000000    0.166700     0.000000     0.000000
# 25%       1.000000     0.000000   21.000000     0.000000     0.000000
# 50%       3.000000     0.000000   28.000000     0.000000     0.000000
# 75%       3.000000     1.000000   39.000000     1.000000     0.000000
# max       3.000000     1.000000   80.000000     8.000000     9.000000
#
#                fare        body
# count  1.219000e+03  109.000000
# mean   3.499074e+05  156.091743
# std    5.320825e+05   93.785269
# min    0.000000e+00    4.000000
# 25%    7.925000e+04   72.000000
# 50%    1.524580e+05  149.000000
# 75%    3.300000e+05  236.000000
# max    5.123292e+06  327.000000

# %%
# graficar nulos

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
sn.set(font_scale=1)
import matplotlib
matplotlib.style.use("ggplot")
null_columns=df.columns[df.isnull().any()]

#pd.options display.mpl.style="difault"
labels=[]
values=[]
for col in null_columns:
    labels.append(col)
    values.append(df[col].isnull().sum())
ind=np.arange(len(labels))
ind
width=0.6

fig,ax=plt.subplots(figsize=(6,5))
rects=ax.barh(ind,np.array(values),color="purple")
ax.set_yticks(ind+(width)/2.)
ax.set_yticklabels(labels,rotation="horizontal")
ax.set_xlabel("Cuenta de valores nulos")
ax.set_ylabel("Nombre de columnas")
ax.set_title("Variables con valores nulos");

# %%
df.dtypes
# Out:
# pclass       float64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# a) Describir brevemente la cantidad de valores faltantes para cada una de las variables de la base de datos
# Es para ver la cantidad de nulos por columnas

print(df.isnull().sum())
# Out:
# pclass         76
# survived        0
# name            0
# sex             0
# age           239
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin         927
# embarked        2
# boat          751
# body         1110
# home.dest     475
# dtype: int64

# %%
# b) En la columna Pclass, completar los valores NA, asignando a las personas a la clase 2
df["pclass"]=df["pclass"].fillna(2.0)
print(df.isnull().sum())
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           239
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin         927
# embarked        2
# boat          751
# body         1110
# home.dest     475
# dtype: int64

# %%
# Para saber el porcentaje de nulos que tiene la columna cabin. No se puede imputar porque es muy alto
print(df.shape[0])
print(df.shape[1])
print("porcentaje de nulos")
print((df.cabin.isnull().sum()*100/df.shape[0]))
# Out:
# 1219
# 14
# porcentaje de nulos
# 76.0459392945037

# %%
df.head(428)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 423     2.0         0                     Gillespie, Mr. William Henry
# 424     2.0         0                      Givard, Mr. Hans Kristensen
# 425     2.0         0                            Greenberg, Mr. Samuel
# 426     2.0         0                               Hale, Mr. Reginald
# 427     2.0         1                        Hamalainen, Master. Viljo
#
#         sex      age  sibsp  parch  ticket       fare    cabin embarked boat  \
# ...

# %%
df.dtypes
# Out:
# pclass       float64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Me imprime las columnas
print(df.columns)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# Muestra los ultimos registros
df.tail(8)
# Out:
#       pclass  survived                                             name  \
# 1211     3.0         0  Skoog, Mrs. William (Anna Bernhardina Karlsson)
# 1212     3.0         0                             Slabenoff, Mr. Petco
# 1213     3.0         0                    Slocovski, Mr. Selman Francis
# 1214     3.0         0                              Smiljanic, Mr. Mile
# 1215     3.0         0                                Smith, Mr. Thomas
# 1216     3.0         1                               Smyth, Miss. Julia
# 1217     3.0         0       Soholt, Mr. Peter Andreas Lauritz Andersen
# 1218     3.0         0                    Somerton, Mr. Francis William
#
#         sex   age  sibsp  parch           ticket      fare  cabin embarked  \
# 1211  Mujer  45.0      1      4           347088  279000.0    NaN        S
# 1212   male   NaN      0      0           349214   78958.0    NaN        S
# 1213   male   NaN      0      0  SOTON/OQ 392086   80500.0    NaN        S
# ...

# %%
# muestra registros aleatorios
df.sample(15)
# Out:
#       pclass  survived                                               name  \
# 540      2.0         1                           Quick, Miss. Phyllis May
# 71       1.0         0                           Clark, Mr. Walter Miller
# 16       1.0         0                           Baxter, Mr. Quigg Edmond
# 174      1.0         0                            Kent, Mr. Edward Austin
# 467      2.0         1                Kantor, Mrs. Sinai (Miriam Sternin)
# 247      1.0         1     Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# 75       1.0         0                         Colley, Mr. Edward Pomeroy
# 47       1.0         1                  Calderhead, Mr. Edward Pennington
# 50       1.0         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 1081     3.0         1                      O'Leary, Miss. Hanora "Norah"
# 502      2.0         1          Mellinger, Mrs. (Elizabeth Anne Maidment)
# 585      2.0         0                                 Weisz, Mr. Leopold
# ...

# %%
#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1219 entries, 0 to 1218
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1219 non-null   float64
#  1   survived   1219 non-null   int64
#  2   name       1219 non-null   object
#  3   sex        1219 non-null   object
#  4   age        980 non-null    float64
#  5   sibsp      1219 non-null   int64
#  6   parch      1219 non-null   int64
#  7   ticket     1219 non-null   object
#  8   fare       1219 non-null   float64
#  9   cabin      292 non-null    object
#  10  embarked   1217 non-null   object
#  11  boat       468 non-null    object
#  12  body       109 non-null    float64
#  13  home.dest  744 non-null    object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 133.5+ KB

# %%
# Una alternativa sería reemplazar los valores “?” por valor “nan” (es decir, nulo o vacío)
# veamos cómo se resolvería esta situación

for col in df.columns:
    df[col].replace({"?":np.nan},inplace=True)

df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           239
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin         927
# embarked        2
# boat          751
# body         1110
# home.dest     475
# dtype: int64

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0         1                    Allen, Miss. Elisabeth Walton  female
# 1     1.0         1                   Allison, Master. Hudson Trevor    male
# 2     1.0         0                     Allison, Miss. Helen Loraine  female
# 3     1.0         0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  2113375.0       B5        S    2    NaN
# 1   0.9167      1      2  113781  1515500.0  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  1515500.0  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  1515500.0  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  1515500.0  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# Mapa de calor.  indica la distribución espacial o temporalmente variable en una matriz mediante el color.

sns.heatmap(df.isnull(),cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
# SOLUCION
# rellenar los espacios vacíos para las variables numéricas con el valor de la media:

num_col=["pclass","body"]
for col in num_col:
    df[col]=pd.to_numeric(df[col])
    df[col].fillna(df[col].mean(),inplace=True)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0         1                    Allen, Miss. Elisabeth Walton  female
# 1     1.0         1                   Allison, Master. Hudson Trevor    male
# 2     1.0         0                     Allison, Miss. Helen Loraine  female
# 3     1.0         0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket       fare    cabin embarked boat  \
# 0  29.0000      0      0   24160  2113375.0       B5        S    2
# 1   0.9167      1      2  113781  1515500.0  C22 C26        S   11
# 2   2.0000      1      2  113781  1515500.0  C22 C26        S  NaN
# 3  30.0000      1      2  113781  1515500.0  C22 C26        S  NaN
# 4  25.0000      1      2  113781  1515500.0  C22 C26        S  NaN
#
#          body                        home.dest
# 0  156.091743                     St Louis, MO
# ...

# %%
# Mapa de calor.  indica la distribución espacial o temporalmente variable en una matriz mediante el color.

sns.heatmap(df.isnull(),cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df.head(40)
# Out:
#     pclass  survived                                               name  \
# 0      1.0         1                      Allen, Miss. Elisabeth Walton
# 1      1.0         1                     Allison, Master. Hudson Trevor
# 2      1.0         0                       Allison, Miss. Helen Loraine
# 3      1.0         0               Allison, Mr. Hudson Joshua Creighton
# 4      1.0         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5      1.0         1                                Anderson, Mr. Harry
# 6      1.0         1                  Andrews, Miss. Kornelia Theodosia
# 7      1.0         0                             Andrews, Mr. Thomas Jr
# 8      1.0         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9      1.0         0                            Artagaveytia, Mr. Ramon
# 10     1.0         0                             Astor, Col. John Jacob
# 11     1.0         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
df.head(20)
# Out:
#     pclass  survived                                               name  \
# 0      1.0         1                      Allen, Miss. Elisabeth Walton
# 1      1.0         1                     Allison, Master. Hudson Trevor
# 2      1.0         0                       Allison, Miss. Helen Loraine
# 3      1.0         0               Allison, Mr. Hudson Joshua Creighton
# 4      1.0         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5      1.0         1                                Anderson, Mr. Harry
# 6      1.0         1                  Andrews, Miss. Kornelia Theodosia
# 7      1.0         0                             Andrews, Mr. Thomas Jr
# 8      1.0         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9      1.0         0                            Artagaveytia, Mr. Ramon
# 10     1.0         0                             Astor, Col. John Jacob
# 11     1.0         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
df.head(428)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 423     2.0         0                     Gillespie, Mr. William Henry
# 424     2.0         0                      Givard, Mr. Hans Kristensen
# 425     2.0         0                            Greenberg, Mr. Samuel
# 426     2.0         0                               Hale, Mr. Reginald
# 427     2.0         1                        Hamalainen, Master. Viljo
#
#         sex      age  sibsp  parch  ticket       fare    cabin embarked boat  \
# ...

# %%
# b) En la columna Pclass, completar los valores NA, asignando a las personas a la clase 2
df["pclass"]=df["pclass"].fillna(2.0)
print(df.isnull().sum())
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age          239
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin        927
# embarked       2
# boat         751
# body           0
# home.dest    475
# dtype: int64

# %%
df.head(428)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 423     2.0         0                     Gillespie, Mr. William Henry
# 424     2.0         0                      Givard, Mr. Hans Kristensen
# 425     2.0         0                            Greenberg, Mr. Samuel
# 426     2.0         0                               Hale, Mr. Reginald
# 427     2.0         1                        Hamalainen, Master. Viljo
#
#         sex      age  sibsp  parch  ticket       fare    cabin embarked boat  \
# ...

# %%
df.corr().style.background_gradient(cmap="coolwarm")
# Out:
# C:\Users\Danilo\AppData\Local\Temp\ipykernel_10960\1464306230.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient(cmap="coolwarm")
# <style type="text/css">
# #T_dc6dd_row0_col0, #T_dc6dd_row1_col1, #T_dc6dd_row2_col2, #T_dc6dd_row3_col3, #T_dc6dd_row4_col4, #T_dc6dd_row5_col5, #T_dc6dd_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dc6dd_row0_col1, #T_dc6dd_row0_col2, #T_dc6dd_row0_col5, #T_dc6dd_row0_col6, #T_dc6dd_row2_col3, #T_dc6dd_row2_col4, #T_dc6dd_row3_col6, #T_dc6dd_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dc6dd_row0_col3, #T_dc6dd_row1_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_dc6dd_row0_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_dc6dd_row1_col0 {
# ...

# %%
# los blockplots
df.boxplot(grid=False, rot=45, fontsize=45)
import plotly.express as px
fig=px.box(df)
fig.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 df.boxplot(grid=False, rot=45, fontsize=45)
#       3 import plotly.express as px
# ----> 4 fig=px.box(df)
#       5 fig.show
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:666, in box(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, orientation, boxmode, log_x, log_y, range_x, range_y, points, notched, title, template, width, height)
#     625 def box(
#     626     data_frame=None,
#     627     x=None,
#    (...)
#     655     height=None,
#     656 ) -> go.Figure:
#     657     """
#     658     In a box plot, rows of `data_frame` are grouped together into a
# ...

# %%
for feature in continuous_data_cols:
    plt.figure(figsize=(10,6))
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel[feature]
    plt.ylabel("count")
    plt.title(feature)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 for feature in continuous_data_cols:
#       2     plt.figure(figsize=(10,6))
#       3     data=df.copy()
#
# NameError: name 'continuous_data_cols' is not defined

# %%
df.head(225)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 220     1.0         1                     Ostby, Miss. Helene Ragnhild
# 221     1.0         0                   Ostby, Mr. Engelhart Cornelius
# 222     1.0         0                  Ovies y Rodriguez, Mr. Servando
# 223     1.0         0                    Parr, Mr. William Henry Marsh
# 224     1.0         0                              Partner, Mr. Austen
#
#         sex      age  sibsp  parch    ticket       fare    cabin embarked  \
# ...

# %%
# c) En la clase “Sex”, imputar los datos de manera de poder completar la base solo con los valores “male” y “female”
df1=df.replace("Hombre","male").replace("Mujer","female")
df1.head(225)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 220     1.0         1                     Ostby, Miss. Helene Ragnhild
# 221     1.0         0                   Ostby, Mr. Engelhart Cornelius
# 222     1.0         0                  Ovies y Rodriguez, Mr. Servando
# 223     1.0         0                    Parr, Mr. William Henry Marsh
# 224     1.0         0                              Partner, Mr. Austen
#
#         sex      age  sibsp  parch    ticket       fare    cabin embarked  \
# ...

# %%
# d) En los casos de las personas de las cuales no se tenga la edad, rellenar los datos con el promedio de edad de aquellos que sí tienen el dato.

df1["age"]=df1["age"].fillna(df["age"].mean())
print(df.isnull().sum())
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age          239
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin        927
# embarked       2
# boat         751
# body           0
# home.dest    475
# dtype: int64

# %%
# En la columna embarked, asignar el valor “S” a aquellos datos que se encuentran con valor vacío.
df1["embarked"]=df1["embarked"],fillna("S")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 # En la columna embarked, asignar el valor “S” a aquellos datos que se encuentran con valor vacío.
# ----> 2 df1["embarked"]=df1["embarked"],fillna("S")
#
# NameError: name 'fillna' is not defined

# %%
df1.head(175)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 170     1.0         1                          Ismay, Mr. Joseph Bruce
# 171     1.0         0                       Jones, Mr. Charles Cresson
# 172     1.0         0                         Julian, Mr. Henry Forbes
# 173     1.0         0                               Keeping, Mr. Edwin
# 174     1.0         0                          Kent, Mr. Edward Austin
#
#         sex      age  sibsp  parch  ticket       fare        cabin embarked  \
# ...

# %%
df1.head(170)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 165     1.0         1                     Hoyt, Mr. Frederick Maxfield
# 166     1.0         0                         Hoyt, Mr. William Fisher
# 167     1.0         1  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# 168     1.0         1                              Icard, Miss. Amelie
# 169     1.0         0                       Isham, Miss. Ann Elizabeth
#
#         sex        age  sibsp  parch    ticket       fare    cabin embarked  \
# ...

# %%
# e) En la columna embarked, asignar el valor “S” a aquellos datos que se encuentran con valor vacío.
df1["embarked"]=df1["embarked"].fillna("S")
df1.head(175)
# Out:
#      pclass  survived                                             name  \
# 0       1.0         1                    Allen, Miss. Elisabeth Walton
# 1       1.0         1                   Allison, Master. Hudson Trevor
# 2       1.0         0                     Allison, Miss. Helen Loraine
# 3       1.0         0             Allison, Mr. Hudson Joshua Creighton
# 4       1.0         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 170     1.0         1                          Ismay, Mr. Joseph Bruce
# 171     1.0         0                       Jones, Mr. Charles Cresson
# 172     1.0         0                         Julian, Mr. Henry Forbes
# 173     1.0         0                               Keeping, Mr. Edwin
# 174     1.0         0                          Kent, Mr. Edward Austin
#
#         sex      age  sibsp  parch  ticket       fare        cabin embarked  \
# ...

# %%
# graficar nulos

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
sn.set(font_scale=1)
import matplotlib
matplotlib.style.use("ggplot")
null_columns=df.columns[df1.isnull().any()]

#pd.options display.mpl.style="difault"
labels=[]
values=[]
for col in null_columns:
    labels.append(col)
    values.append(df[col].isnull().sum())
ind=np.arange(len(labels))
ind
width=0.6

fig,ax=plt.subplots(figsize=(6,5))
rects=ax.barh(ind,np.array(values),color="purple")
ax.set_yticks(ind+(width)/2.)
ax.set_yticklabels(labels,rotation="horizontal")
ax.set_xlabel("Cuenta de valores nulos")
ax.set_ylabel("Nombre de columnas")
ax.set_title("Variables con valores nulos");

# %%
df.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age          239
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin        927
# embarked       2
# boat         751
# body           0
# home.dest    475
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin        927
# embarked       0
# boat         751
# body           0
# home.dest    475
# dtype: int64
